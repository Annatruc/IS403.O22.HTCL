# %%
import pandas as pd
from scipy.stats import levene
from statsmodels.stats.multicomp import pairwise_tukeyhsd
df=pd.read_csv('Exercise_4_Final.csv')
df
# Out:
#          Unnamed: 0   Khoi   Diem
# 0                 0  KhoiC  13.25
# 1                 1  KhoiC  22.50
# 2                 2  KhoiA  17.25
# 3                 3  KhoiB  16.50
# 4                 4  KhoiC  14.00
# ...             ...    ...    ...
# 1073348     1073348  KhoiB  12.95
# 1073349     1073349  KhoiA  21.55
# 1073350     1073350  KhoiB  17.05
# 1073351     1073351  KhoiA  16.80
# 1073352     1073352  KhoiB  13.80
#
# [1073353 rows x 3 columns]

# %%
# repaired_df = pd.melt(df, var_name='Khoi', value_name='Diem')
repaired_df = df.groupby('Khoi')['Diem'].apply(list)
repaired_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b1a9ac0eb790> in <cell line: 2>()
#       1 # repaired_df = pd.melt(df, var_name='Khoi', value_name='Diem')
# ----> 2 repaired_df = df.groupby('Khoi')['Diem'].apply(list)
#       3 repaired_df
#
# NameError: name 'df' is not defined

# %%
st, pval = levene(*repaired_df, center="mean")
st, pval
# Out:
# (3416.0002506138303, 0.0)

# %%
from scipy.stats import f_oneway

fvalue, pvalue = f_oneway(*repaired_df)
fvalue, pvalue
# Out:
# (6788.78521446278, 0.0)
