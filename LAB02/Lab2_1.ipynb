# %%
import pandas as pd
import numpy as np
import statistics as st

# %%
drink = pd.read_csv("eds.csv", delimiter = ",")
drink
# Out:
#     Gender    Brand
# 0     Male  Brand 3
# 1   Female  Brand 3
# 2     Male  Brand 3
# 3     Male  Brand 1
# 4     Male  Brand 1
# ..     ...      ...
# 95    Male  Brand 1
# 96    Male  Brand 3
# 97  Female  Brand 3
# 98    Male  Brand 2
# 99  Female  Brand 1
#
# [100 rows x 2 columns]

# %%
chisqt = pd.crosstab(drink.Gender, drink.Brand)
chisqt
# Out:
# Brand   Brand 1  Brand 2  Brand 3
# Gender
# Female        9        6       22
# Male         25       17       21

# %%
from scipy import stats

# %%
c, p, dof, exp = stats.chi2_contingency(chisqt)

# %%
p
# Out:
# 0.038921342064441915

# %%
c
# Out:
# 6.4924250792329055

# %%
dof
# Out:
# 2

# %%
exp
# Out:
# array([[12.58,  8.51, 15.91],
#        [21.42, 14.49, 27.09]])
