# %%
import pandas as pd
import numpy as np
from scipy import stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv('DATA_2A.csv')
df.head(5)
# Out:
#      School        Type  Median SAT Acceptance Rate Expenditures/Student  \
# 0   Amherst    Lib Arts        1315             22%             $26,636
# 1   Barnard    Lib Arts        1220             53%             $17,653
# 2     Bates    Lib Arts        1240             36%             $17,554
# 3  Berkeley  University        1176             37%             $23,665
# 4   Bowdoin    Lib Arts        1300             24%             $25,703
#
#    Top 10% HS  Graduation %
# 0          85            93
# 1          69            80
# 2          58            88
# 3          95            68
# 4          78            90

# %%
graduation = df['Graduation %']

median_sat = df['Median SAT']

df['Expenditures/Student'] = df['Expenditures/Student'].replace({'\$': '', ',': ''}, regex=True).astype(float)
top=df['Top 10% HS']

expend=df['Expenditures/Student']

df['Acceptance Rate'] = df['Acceptance Rate'].replace({'%': '', ',': ''}, regex=True).astype(float)
accept=df['Acceptance Rate']
df.head(5)
# Out:
#      School        Type  Median SAT  Acceptance Rate  Expenditures/Student  \
# 0   Amherst    Lib Arts        1315             22.0               26636.0
# 1   Barnard    Lib Arts        1220             53.0               17653.0
# 2     Bates    Lib Arts        1240             36.0               17554.0
# 3  Berkeley  University        1176             37.0               23665.0
# 4   Bowdoin    Lib Arts        1300             24.0               25703.0
#
#    Top 10% HS  Graduation %
# 0          85            93
# 1          69            80
# 2          58            88
# 3          95            68
# 4          78            90

# %%
x=np.array(df[["Median SAT","Acceptance Rate","Expenditures/Student","Top 10% HS"]]).reshape((-1, 4))
y=np.array(graduation).reshape((-1, 1))

# %% [markdown]
# ## LinearRegression

# %%
# Create model
model = LinearRegression()
# Train model
model.fit(x,y)
# Out:
# LinearRegression()

# %%
print("Intercept term: ",model.intercept_)
print("R_coef: ", model.coef_)
print("R Square: ", model.score(x, y))
# Out:
# Intercept term:  [17.92095587]
# R_coef:  [[ 7.20062848e-02 -2.48592318e-01 -1.35649860e-04 -1.62764489e-01]]
# R Square:  0.5344260406481331

# %% [markdown]
# ## MultipleLinearRegression

# %% [markdown]
# ### Create constant variable

# %%
x1=sm.add_constant(x)

# %% [markdown]
# ### Run MLR: The same as SLR

# %%
results_mul=sm.OLS(y,x1).fit()
results_mul.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.534
# Model:                            OLS   Adj. R-squared:                  0.492
# Method:                 Least Squares   F-statistic:                     12.63
# Date:                Sun, 07 Apr 2024   Prob (F-statistic):           6.33e-07
# Time:                        11:10:33   Log-Likelihood:                -148.69
# No. Observations:                  49   AIC:                             307.4
# Df Residuals:                      44   BIC:                             316.8
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         17.9210     24.557      0.730      0.469     -31.571      67.413
# ...

# %%
graduation =  17.9210  + 0.0720*1220 + (-0.2486) + (-0.0001) + (-0.1628)
graduation
# Out:
# 105.34949999999999
